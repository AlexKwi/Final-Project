# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
pgh_arrest_data = pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f",
                           index_col="ARRESTTIME", 
                           parse_dates=True)
pop_data = pd.read_csv('total-population.csv', index_col="Neighborhood")
pop_data.head()
#pgh_arrest_data.head()
# Out:
#                    Id  Estimate; Total  Margin of Error; Total
# Neighborhood
# Allegheny Center    1           1411.0              196.000000
# Allegheny West      2            343.0               96.000000
# Allentown           3           2558.0              449.773276
# Arlington           4           1852.0              348.188168
# Arlington Heights   5            272.0              126.000000

# %%
pgh_arrest_data = pgh_arrest_data.rename(columns={'INCIDENTNEIGHBORHOOD':'Neighborhood', 'OFFENSES':'Offenses'})
arrest_data = pgh_arrest_data.loc[:,["Offenses","Neighborhood"]].groupby('Neighborhood').count()
# Out:
#                    Offenses
# Neighborhood
# Allegheny Center        653
# Allegheny West           75
# Allentown               539
# Arlington               168
# Arlington Heights       100

# %%
population = pop_data.loc[:,"Estimate; Total"]
arrest_data['Estimated Population'] = population
arrest_data['Offenses per Capita'] = arrest_data.loc[:,"Offenses"]/arrest_data.loc[:,'Estimated Population']
arrest_data.dropna()
# Out:
#                            Offenses  Estimated Population  Offenses per Capita
# Neighborhood
# Allegheny Center                653                1411.0             0.462792
# Allegheny West                   75                 343.0             0.218659
# Allentown                       539                2558.0             0.210711
# Arlington                       168                1852.0             0.090713
# Arlington Heights               100                 272.0             0.367647
# Banksville                      142                3858.0             0.036807
# Bedford Dwellings               336                1349.0             0.249073
# Beechview                       687                8078.0             0.085046
# Beltzhoover                     315                1702.0             0.185076
# Bloomfield                      552                8669.0             0.063675
# Bluff                           786                6294.0             0.124881
# Bon Air                         125                 920.0             0.135870
# Brighton Heights                612                7421.0             0.082469
# Brookline                       693               13160.0             0.052660
# California-Kirkbride            152                 803.0             0.189290
# Carrick                        1316               10122.0             0.130014
# Central Business District      2136                4060.0             0.526108
# Central Lawrenceville           272                4775.0             0.056963
# Central Northside                23                2892.0             0.007953
# Central Oakland                 304                5822.0             0.052216
# Chartiers City                   23                 560.0             0.041071
# Chateau                         263                   3.0            87.666667
# Crafton Heights                 293                3964.0             0.073915
# Crawford-Roberts                470                2225.0             0.211236
# Duquesne Heights                103                2522.0             0.040841
# East Allegheny                 1235                2095.0             0.589499
# East Carnegie                    28                 610.0             0.045902
# East Hills                      581                2859.0             0.203218
# East Liberty                    999                5537.0             0.180423
# Elliott                         349                2491.0             0.140104
# ...                             ...                   ...                  ...
# Perry North                     402                3771.0             0.106603
# Perry South                     637                3398.0             0.187463
# Point Breeze                    184                5414.0             0.033986
# Point Breeze North              135                1732.0             0.077945
# Polish Hill                      98                1331.0             0.073629
# Regent Square                    19                1033.0             0.018393
# Ridgemont                        13                 314.0             0.041401
# Shadyside                       545               13562.0             0.040186
# Sheraden                        661                5684.0             0.116291
# South Oakland                   173                2921.0             0.059226
# South Shore                     158                  12.0            13.166667
# South Side Flats               1954                6292.0             0.310553
# South Side Slopes               458                4583.0             0.099935
# Spring Garden                   152                 840.0             0.180952
# Spring Hill-City View           434                2456.0             0.176710
# Squirrel Hill North             151               11336.0             0.013320
# Squirrel Hill South             443               16042.0             0.027615
# St. Clair                        30                 270.0             0.111111
# Stanton Heights                 115                4761.0             0.024155
# Strip District                  269                 747.0             0.360107
# Summer Hill                      45                1191.0             0.037783
# Swisshelm Park                   20                1345.0             0.014870
# Terrace Village                 142                2292.0             0.061955
# Troy Hill                       258                2283.0             0.113009
# Upper Hill                      219                1884.0             0.116242
# Upper Lawrenceville             113                2754.0             0.041031
# West End                        153                 235.0             0.651064
# West Oakland                    178                1717.0             0.103669
# Westwood                        119                3537.0             0.033644
# Windgap                          60                1534.0             0.039113
#
# [89 rows x 3 columns]

# %%
arrest_data_filtered = arrest_data[arrest_data['Offenses per Capita']<.03]
arrest_data_filtered
# Out:
#                      Offenses  Estimated Population  Offenses per Capita
# Neighborhood
# Central Northside          23                2892.0             0.007953
# Lincoln Place             101                3499.0             0.028865
# New Homestead              22                 973.0             0.022610
# North Oakland             223                9602.0             0.023224
# Regent Square              19                1033.0             0.018393
# Squirrel Hill North       151               11336.0             0.013320
# Squirrel Hill South       443               16042.0             0.027615
# Stanton Heights           115                4761.0             0.024155
# Swisshelm Park             20                1345.0             0.014870

# %%
arrest_data_filtered.loc[:,'Offenses per Capita'].plot(kind="bar")
